# %% [markdown]
# <a href="https://colab.research.google.com/github/Baba905/Baba905/blob/main/Initiation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello git')
# Out:
# Hello git

# %%
import pandas as pd

# %%
ls
# Out:
# bin/      dev/   lib32/  NGC-DL-CONTAINER-LICENSE  root/           srv/    usr/
# boot/     etc/   lib64/  opt/                      run/            sys/    var/
# content/  home/  media/  proc/                     sales_data.csv  tmp/
# datalab/  lib/   mnt/    python-apt/               sbin/           tools/

# %%
sales = pd.read_csv('sales_data.csv')

# %%
sales.shape
# Out:
# (226072, 18)

# %%
#give us the column details like type of data, the name 
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226072 entries, 0 to 226071
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              226072 non-null  object
#  1   Day               226072 non-null  object
#  2   Month             226072 non-null  object
#  3   Year              226072 non-null  int64
#  4   Customer_Age      226072 non-null  object
#  5   Age_Group         226072 non-null  object
#  6   Customer_Gender   226072 non-null  object
#  7   Country           226072 non-null  object
#  8   State             226072 non-null  object
#  9   Product_Category  226072 non-null  object
#  10  Sub_Category      226072 non-null  object
#  11  Product           226072 non-null  object
#  12  Order_Quantity    226072 non-null  int64
#  13  Unit_Cost         226072 non-null  int64
#  14  Unit_Price        226072 non-null  int64
#  15  Profit            226072 non-null  int64
# ...

# %%
sales.head()
# Out:
#          Date Day     Month  Year Customer_Age       Age_Group  \
# 0  2013-11-26  26  November  2013           19     Youth (<25)
# 1  2015-11-26  26  November  2015           19     Youth (<25)
# 2  2014-03-23  23     March  2014           49  Adults (35-64)
# 3  2016-03-23  23     March  2016           49  Adults (35-64)
# 4  2014-05-15  15       May  2014           47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
#Give information about series like the  mean, standard deviation, the quantiles min, max, the type
sales['Year'].describe()

# %%
sales['Profit'].plot(kind="density")

# %%
sales.loc[sales['Country']=='France']
# Out:
#               Date Day      Month  Year Customer_Age             Age_Group  \
# 55      2013-07-15  15       July  2013           52        Adults (35-64)
# 56      2015-07-15  15       July  2015           52        Adults (35-64)
# 57      2013-08-17  17     August  2013           43        Adults (35-64)
# 58      2015-08-17  17     August  2015           43        Adults (35-64)
# 65      2013-09-24  24  September  2013           32  Young Adults (25-34)
# ...            ...  ..        ...   ...          ...                   ...
# 226015  2015-09-08   8  September  2015           31  Young Adults (25-34)
# 226036  2014-07-27  27       July  2014           34  Young Adults (25-34)
# 226037  2016-07-27  27       July  2016           34  Young Adults (25-34)
# 226070  2014-03-04   4      March  2014           37        Adults (35-64)
# 226071  2016-03-04   4      March  2016           37        Adults (35-64)
#
# ...
